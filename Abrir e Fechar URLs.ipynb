# %% [markdown]
# <a href="https://colab.research.google.com/github/cleomarbrdias/script/blob/main/Abrir%20e%20Fechar%20URLs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import webbrowser
import time
import os
import signal
import psutil  # instale com: pip install psutil

# Lista de URLs
urls = [
    "https://docs.google.com/spreadsheets/d/e/2PACX-1vTxR_GLRUjhnqrarpfFAAWkxf8a-lAaKm0nyq0v1DnSVtit7Vp2eGS5SWY00OEL0w/pub?output=csv",
    "https://docs.google.com/spreadsheets/d/e/2PACX-1vTg11j3cj8ab268vQsQvcN9uqDa_pcPMjyACehE8wXnTipUvAvloWoIzP0lmxHKJA/pub?output=csv",
    "https://docs.google.com/spreadsheets/d/e/2PACX-1vRIUgKdYwBVQubvxWF1L_ngApb0H_wAp1wuO5_-a8JqSgVPYp5u63Rk0QuI_UoCfg/pub?output=csv",
    "https://docs.google.com/spreadsheets/d/e/2PACX-1vS3_AC8TzqcSmpKRYw3crIAI76yJ3V6TWqYVOEjHLTXbFvK_KDnvwqLuWD-P6kILw/pub?output=csv",
    "https://docs.google.com/spreadsheets/d/e/2PACX-1vSmyhea1Bbp5z4sf6p1bv7iPHYgoiattK0i04Xt6AK_Lt3UeCO5MxxSW3-_1yg6_A/pub?output=csv",
    "https://docs.google.com/spreadsheets/d/e/2PACX-1vQDtfNGX7Njxxa1qEzIk9KafkiZXyRWP1CWLorfRzcJHzMtNMgs3TXLB6Wz4upLQg/pub?output=csv",
    "https://docs.google.com/spreadsheets/d/e/2PACX-1vTh2Rwe-FadwNNVkLy1cmI5F7M9WhF8DLc4DBXPzUzfaFruCuSBDOTZIuUwH_hEPw/pub?output=csv",
    "https://docs.google.com/spreadsheets/d/e/2PACX-1vS2TmooQ944bWkLTncHRzy2BZyKJVKPlCx2s7JHxXIvnvFAcglFIXZyZViodvVUPw/pub?output=csv",
    "https://docs.google.com/spreadsheets/d/e/2PACX-1vRUSmHCU7cgtOH_6hUt-VRb3sl_rauL-keS8ve6PdSSe0wWrAy86dMzNTgqxmp4zQ/pub?output=csv",
    "https://docs.google.com/spreadsheets/d/e/2PACX-1vQ606qk6C2qTtzRu2bJ9Dut3TRMSDfJw5qZhCI7bOYp7UgQ_oocPnceq3irRKIscQ/pub?output=csv",
    "https://docs.google.com/spreadsheets/d/e/2PACX-1vTG9ramYoyAigAshRuIOfC8yVToI-uuGsaFSbO6wrFrU47fTROC0Z4J_opNF9IAAw/pub?output=csv",
    "https://docs.google.com/spreadsheets/d/e/2PACX-1vRetw-OuYak5FmuZDhQWDy8uM8BhbCN3nA3vyqDenXBiyeCx3Ymetoac9DPD-m4jg/pub?output=csv",
    "https://docs.google.com/spreadsheets/d/e/2PACX-1vRzBkmYZoVnUv4Y6NyCh_UfY6ONmSQvq4-Mjt3wXjXmSSgl2KPibuhv-9o_Vry0kQ/pub?output=csv",
    "https://docs.google.com/spreadsheets/d/e/2PACX-1vSTu3aYp9NMJ-u3U1kWLIMMxCj3yZpcKUtlWLR3SveM-r3e5lkE8Okddck5qHSRRw/pub?output=csv"

]

# Tempo em segundos que cada aba ficará aberta
tempo_aberto = 5

# Função para tentar fechar o navegador (opcional, depende do SO)
def fechar_navegador():
    for proc in psutil.process_iter(['pid', 'name']):
        if proc.info['name'] and (
            "chrome" in proc.info['name'].lower() or
            "firefox" in proc.info['name'].lower() or
            "msedge" in proc.info['name'].lower()
        ):
            try:
                proc.terminate()
            except Exception as e:
                print(f"Não foi possível encerrar {proc.info['name']}: {e}")

# Loop para abrir e fechar
for url in urls:
    print(f"Abrindo {url} ...")
    webbrowser.open(url)
    time.sleep(tempo_aberto)
    print(f"Fechando navegador...")
    fechar_navegador()
    time.sleep(2)

print("Todas as URLs foram abertas e fechadas com sucesso!")
# Out:
# Abrindo https://docs.google.com/spreadsheets/d/1nyFb0n6Yn847fJiw1MOF4YefdFGxOdIT/edit?usp=drivesdk&ouid=103251845361125712060&rtpof=true&sd=true ...
# Fechando navegador...
# Abrindo https://docs.google.com/spreadsheets/d/1nwV16CXagoRkb2G_1grxUyPXHfEP_xvd/edit?usp=drivesdk&ouid=103251845361125712060&rtpof=true&sd=true ...
# Fechando navegador...
# Abrindo https://docs.google.com/spreadsheets/d/1nt_htgFYDQR9RKbX_hFVM3c6a9mpbPaW/edit?usp=drivesdk&ouid=103251845361125712060&rtpof=true&sd=true ...
# Fechando navegador...
# Abrindo https://docs.google.com/spreadsheets/d/1oIAicSVAKym0CK140VRM7eEeJFbLAIve/edit?usp=drivesdk&ouid=103251845361125712060&rtpof=true&sd=true ...
# Fechando navegador...
# Todas as URLs foram abertas e fechadas com sucesso!
